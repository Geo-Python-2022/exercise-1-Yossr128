# %%
ice_cream_rating=10

# %%
sleeping_rating=8

# %%
input()
# Out:
#  o
# 'o'

# %%
first_name=input()
# Out:
#  Yossr

# %%
first_name
# Out:
# 'Yossr '

# %%
last_name=input()
# Out:
#  Abouelnour

# %%
last_name
# Out:
# 'Abouelnour'

# %%
my_name=first_name + last_name

# %%
my_name
# Out:
# 'Yossr Abouelnour'

# %%
my_name
# Out:
# 'Yossr Abouelnour'

# %%
happiness_rating=(ice_cream_rating+sleeping_rating)/2

# %%
print (happiness_rating)
# Out:
# 9.0

# %%
happiness_rating
# Out:
# 9.0

# %% [markdown]
# All makes sense

# %%
print ("My name is "+my_name+" and I give eating ice cream a score of "+str(ice_cream_rating)+" out of 10!")
#I am (my_name)and my sleeping enjoyment rating is (sleeping_rating) / 10!
#Based on the factors above, my happiness rating is (happiness_rating) out of 10, or happiness_rating*100!
# Out:
# My name is Yossr Abouelnour and I give eating ice cream a score of 10 out of 10!

# %%
print("I am "+my_name+" and my sleeping enjoyment rating is "+str(sleeping_rating)+" /10!")
# Out:
# I am Yossr Abouelnour and my sleeping enjoyment rating is 8 /10!

# %%
print("Based on the factors above, my happiness rating is "+str(happiness_rating)+" out of 10, or "+str(happiness_rating*100/10)+"%!")
# Out:
# Based on the factors above, my happiness rating is 9.0 out of 10, or 90.0%!
